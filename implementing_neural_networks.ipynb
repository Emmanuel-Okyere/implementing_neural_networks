# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, Normalizer
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam

# %%
dataset = pd.read_csv("life_expectancy.csv")
dataset.head()
# Out:
#        Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0               71.279624         65.0      1154   19.1  ...
# 1               73.523582         62.0       492   18.6  ...
# 2               73.219243         64.0       430   18.1  ...
# 3               78.184215         67.0      2787   17.6  ...
# 4                7.097109         68.0      3013   17.2  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# ...

# %%
dataset.describe()
# Out:
#               Year  Adult Mortality  infant deaths      Alcohol  \
# count  2938.000000      2938.000000    2938.000000  2938.000000
# mean   2007.518720       164.725664      30.303948     4.546875
# std       4.613841       124.086215     117.926501     3.921946
# min    2000.000000         1.000000       0.000000     0.010000
# 25%    2004.000000        74.000000       0.000000     1.092500
# 50%    2008.000000       144.000000       3.000000     3.755000
# 75%    2012.000000       227.000000      22.000000     7.390000
# max    2015.000000       723.000000    1800.000000    17.870000
#
#        percentage expenditure  Hepatitis B       Measles          BMI   \
# count             2938.000000  2938.000000    2938.000000  2938.000000
# mean               738.251295    83.022124    2419.592240    38.381178
# std               1987.914858    22.996984   11467.272489    19.935375
# min                  0.000000     1.000000       0.000000     1.000000
# ...

# %%
dataset = dataset.drop(columns = ["Country"], axis = 1)
dataset.head()
# Out:
#    Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  2015  Developing            263.0             62     0.01
# 1  2014  Developing            271.0             64     0.01
# 2  2013  Developing            268.0             66     0.01
# 3  2012  Developing            272.0             69     0.01
# 4  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
#    ...  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
dataset.shape
# Out:
# (2938, 21)

# %%
labels = dataset.iloc[:,-1]
labels.head()
# Out:
# 0    65.0
# 1    59.9
# 2    59.9
# 3    59.5
# 4    59.2
# Name: Life expectancy, dtype: float64

# %%
features = dataset.iloc[:,0:-1]

# %%
features = pd.get_dummies(features)
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, train_size = 0.8, random_state = 1)

# %%
numerical_features = features.select_dtypes(include=['float64', 'int64'])
numerical_columns = numerical_features.columns

# %%
ct = ColumnTransformer([("only numeric", StandardScaler(), numerical_columns)], remainder='passthrough')

features_train_scaled = ct.fit_transform(features_train)
features_test_scaled = ct.fit_transform(features_test)

# %%
my_model = Sequential()
my_model.add(layers.InputLayer(input_shape =dataset.shape[1],))
my_model.add(layers.Dense(16, activation = "relu"))
my_model.add(layers.Dense(1))
my_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 16)                352
#
#  dense_1 (Dense)             (None, 1)                 17
#
# ...
# Total params: 369
# Trainable params: 369
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(learning_rate = 0.01)
my_model.compile(optimizer = opt, metrics = ["mae"], loss = "mse")

# %%
my_model.fit(features_train_scaled, labels_train, epochs = 40, batch_size = 1, verbose = 1)
# Out:
# Epoch 1/40
# 2350/2350 [==============================] - 6s 2ms/step - loss: 230.4074 - mae: 7.9986
# Epoch 2/40
# 2350/2350 [==============================] - 5s 2ms/step - loss: 21.3456 - mae: 3.4479
# Epoch 3/40
# 2350/2350 [==============================] - 5s 2ms/step - loss: 18.9800 - mae: 3.2684
# Epoch 4/40
# 2350/2350 [==============================] - 5s 2ms/step - loss: 18.5513 - mae: 3.2273
# Epoch 5/40
# 2350/2350 [==============================] - 5s 2ms/step - loss: 18.8852 - mae: 3.0984
# Epoch 6/40
# 2350/2350 [==============================] - 5s 2ms/step - loss: 14.9826 - mae: 2.8225
# Epoch 7/40
# 2350/2350 [==============================] - 4s 2ms/step - loss: 15.1570 - mae: 2.7397
# Epoch 8/40
# 2350/2350 [==============================] - 5s 2ms/step - loss: 13.6988 - mae: 2.6656
# Epoch 9/40
# 2350/2350 [==============================] - 5s 2ms/step - loss: 12.0883 - mae: 2.5505
# Epoch 10/40
# ...

# %%
res_mse,res_mae = my_model.evaluate(features_test_scaled,labels_test )
# Out:
# 19/19 [==============================] - 0s 2ms/step - loss: 8.2218 - mae: 2.0937

# %%
print(res_mse, res_mae)
# Out:
# 8.22181224822998 2.0936567783355713
